# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
import matplotlib.dates as mdates
style.use('seaborn')

from sklearn import linear_model 
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# Read in data and format

# %%
def format_data(df):
    
    df.rename(columns = {'Unnamed: 0':'day'}, inplace = True)
    df.drop(columns=['adjClose', 'adjHigh', 'adjLow','adjOpen', 'adjVolume', 
                        'divCash', 'splitFactor'], inplace=True)

    price = df['close']
    price_next_day = df['close'].shift(1)
    df['log_returns'] = np.log(price/price_next_day)
    returns = df['log_returns']

    # buy 1 or sell -1 signals
    df['signal'] = np.sign(df['log_returns'])

    # lags = 21
    # lags = 3
    lags = 5
    cols = []

    for lag in range(1, lags+1):
        col = 'lag_{}'.format(lag)
        df[col] = returns.shift(lag)
        cols.append(col)

    df.dropna(inplace=True)
    return df

# %%
df = pd.read_csv('../data/ETHUSD.csv')
df = format_data(df)

# %%
df.head()
# Out:
#     day        date        close         high          low         open  \
# 6     6  2021-01-08  1216.751571  1262.290424  1085.546172  1225.661462
# 7     7  2021-01-09  1277.456309  1305.823731  1171.661108  1216.669204
# 8     8   2021-01-1  1254.720733  1349.475651  1165.847880  1277.548286
# 9     9  2021-01-11  1087.469986  1260.199167   912.604580  1254.659819
# 10   10  2021-01-12  1050.260409  1150.055396  1006.276283  1087.335624
#
#           volume  log_returns  signal     lag_1     lag_2     lag_3     lag_4  \
# 6   1.797646e+06    -0.006405    -1.0  0.012480  0.094158  0.054970  0.062572
# 7   2.093173e+06     0.048686     1.0 -0.006405  0.012480  0.094158  0.054970
# 8   2.928351e+06    -0.017958    -1.0  0.048686 -0.006405  0.012480  0.094158
# 9   6.565873e+06    -0.143059    -1.0 -0.017958  0.048686 -0.006405  0.012480
# 10  3.285628e+06    -0.034816    -1.0 -0.143059 -0.017958  0.048686 -0.006405
#
#        lag_5
# 6   0.233714
# 7   0.062572
# 8   0.054970
# ...

# %%
df['signal'].value_counts()
# Out:
#  1.0    175
# -1.0    138
# Name: signal, dtype: int64

# %% [markdown]
# Split data in train test data split (no shuffle)

# %%
returns_train
# Out:
#         lag_1     lag_2     lag_3     lag_4     lag_5
# 6    0.012480  0.094158  0.054970  0.062572  0.233714
# 7   -0.006405  0.012480  0.094158  0.054970  0.062572
# 8    0.048686 -0.006405  0.012480  0.094158  0.054970
# 9   -0.017958  0.048686 -0.006405  0.012480  0.094158
# 10  -0.143059 -0.017958  0.048686 -0.006405  0.012480
# ..        ...       ...       ...       ...       ...
# 282 -0.045970  0.003320 -0.006858  0.003270  0.017136
# 283  0.036744 -0.045970  0.003320 -0.006858  0.003270
# 284 -0.014526  0.036744 -0.045970  0.003320 -0.006858
# 285  0.032821 -0.014526  0.036744 -0.045970  0.003320
# 286  0.049579  0.032821 -0.014526  0.036744 -0.045970
#
# [281 rows x 5 columns]

# %%
signal_test.value_counts()
# Out:
# -1.0    18
#  1.0    14
# Name: signal, dtype: int64

# %%
signal_train.value_counts()
# Out:
#  1.0    161
# -1.0    120
# Name: signal, dtype: int64

# %%
type(returns_test)
# Out:
# pandas.core.frame.DataFrame

# %%
lm = linear_model.LogisticRegression(C=1e7, solver='lbfgs')
lm.fit(returns_train, signal_train)
    
signal_p = lm.predict(returns_test) # the output from trained results
signal_prob = lm.predict_proba(returns_test)
# print('signal_prob')
# print(signal_prob)

# print('model score: {}'.format(lm.score(returns_test, signal_test)))

# %%
pd.Series(signal_p).value_counts()
# Out:
#  1.0    31
# -1.0     1
# dtype: int64

# %% [markdown]
# Show Results

# %%
plt.title('ETHUSD Predicted')
plt.scatter(test_date, signal_p, label='Predicted Signals')
# plt.plot(test_date, test_close)
# plt.plot()
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=15))
plt.legend()
plt.show()

# %%
plt.title('ETHUSD True Train')
plt.scatter(train_date, signal_train, label='True Signals')
# plt.plot(test_date, test_close)
# plt.plot(test_date,signal_prob[:,1], 'g-', label='Buy Prob')
# plt.plot(test_date,signal_prob[:,0], 'r--', label='Sell Prob')
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=15))
plt.legend()
plt.show()

# %%
plt.title('ETHUSD True Test')
plt.scatter(test_date, signal_test, label='True Signals')
# plt.plot(test_date, test_close)
# plt.plot(test_date,signal_prob[:,1], 'g-', label='Buy Prob')
# plt.plot(test_date,signal_prob[:,0], 'r--', label='Sell Prob')
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=15))
plt.legend()
plt.show()

# %%
plt.title('ETHUSD Predicted Probabilities')
# plt.scatter(test_date, signal_test, label='True Signals')
# plt.plot(test_date, test_close)
plt.plot(test_date,signal_prob[:,1], 'g-', label='Buy Prob')
plt.plot(test_date,signal_prob[:,0], 'r--', label='Sell Prob')
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=15))
plt.legend()
plt.show()

# %%
plt.title('ETHUSD Close Price')
plt.plot(test_date, test_close)
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=15))
plt.show()

# %% [markdown]
# Check Metrics

# %%
print(accuracy_score(signal_test, signal_p ))
fpr, tpr, thresholds = roc_curve(signal_test, signal_p, pos_label=2)
auc = roc_auc_score(signal_test, signal_p)
print('fpr: {}'.format(fpr))
print('tpr: {}'.format(tpr))
print('thresholds: {}'.format(thresholds))
print('auc: {}'.format(auc))    

plt.plot(fpr,tpr,label="signal data, auc="+str(auc))
plt.show()
# Out:
# 0.40625
# fpr: [0.      0.96875 1.     ]
# tpr: [nan nan nan]
# thresholds: [ 2.  1. -1.]
# auc: 0.4642857142857143
# c:\users\craig\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_ranking.py:811: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "

# %% [markdown]
# Trying with full data set now

# %%
df
# Out:
#      day        date        close         high          low         open  \
# 6      6  2021-01-08  1216.751571  1262.290424  1085.546172  1225.661462
# 7      7  2021-01-09  1277.456309  1305.823731  1171.661108  1216.669204
# 8      8   2021-01-1  1254.720733  1349.475651  1165.847880  1277.548286
# 9      9  2021-01-11  1087.469986  1260.199167   912.604580  1254.659819
# 10    10  2021-01-12  1050.260409  1150.055396  1006.276283  1087.335624
# ..   ...         ...          ...          ...          ...          ...
# 314  314  2021-11-12  4666.496945  4809.226469  4509.583511  4719.821999
# 315  315  2021-11-13  4644.527382  4704.701538  4585.021231  4666.360858
# 316  316  2021-11-14  4626.317297  4695.870000  4514.635312  4647.030000
# 317  317  2021-11-15  4563.918580  4771.690847  4540.045330  4627.312350
# 318  318  2021-11-16  4400.690671  4564.149468  4248.417498  4563.906651
#
#            volume  log_returns  signal     lag_1     lag_2     lag_3  \
# ...

# %%
df['log_returns'].iloc[lags:].value_counts()
# Out:
#  0.031786    1
#  0.010569    1
# -0.003801    1
# -0.021580    1
#  0.104447    1
#             ..
#  0.015795    1
# -0.016263    1
#  0.033969    1
#  0.030554    1
# -0.039255    1
# Name: log_returns, Length: 308, dtype: int64

# %%
lm_full = linear_model.LogisticRegression(C=1e7, solver='lbfgs') 
lm_full.fit(df[cols], df['signal'])


df['predictions'] = lm_full.predict(df[cols])

# df['predictions_p'] = lm_full.predict_proba(df[cols])
hits = np.sign(df['log_returns'].iloc[lags:] * df['predictions'].iloc[lags:]).value_counts()
hits
# Out:
#  1.0    174
# -1.0    134
# dtype: int64

# %%
df
# Out:
#      day        date        close         high          low         open  \
# 6      6  2021-01-08  1216.751571  1262.290424  1085.546172  1225.661462
# 7      7  2021-01-09  1277.456309  1305.823731  1171.661108  1216.669204
# 8      8   2021-01-1  1254.720733  1349.475651  1165.847880  1277.548286
# 9      9  2021-01-11  1087.469986  1260.199167   912.604580  1254.659819
# 10    10  2021-01-12  1050.260409  1150.055396  1006.276283  1087.335624
# ..   ...         ...          ...          ...          ...          ...
# 314  314  2021-11-12  4666.496945  4809.226469  4509.583511  4719.821999
# 315  315  2021-11-13  4644.527382  4704.701538  4585.021231  4666.360858
# 316  316  2021-11-14  4626.317297  4695.870000  4514.635312  4647.030000
# 317  317  2021-11-15  4563.918580  4771.690847  4540.045330  4627.312350
# 318  318  2021-11-16  4400.690671  4564.149468  4248.417498  4563.906651
#
#            volume  log_returns  signal     lag_1     lag_2     lag_3  \
# ...

# %%
df['predictions'].iloc[lags:].value_counts()
# Out:
#  1.0    156
# -1.0    152
# Name: predictions, dtype: int64

# %%
accuracy_score(df['predictions'], np.sign(df['log_returns']))
# Out:
# 0.5335463258785943

# %%
df['strategy'] = df['predictions'] * df['log_returns']

# %%
df[['strategy', 'log_returns']].cumsum().apply(np.exp).plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df['strategy']
# Out:
# 6      0.006405
# 7      0.048686
# 8     -0.017958
# 9      0.143059
# 10    -0.034816
#          ...
# 314   -0.011421
# 315    0.004719
# 316   -0.003928
# 317   -0.013580
# 318    0.036420
# Name: strategy, Length: 313, dtype: float64

# %%
df['log_returns']
# Out:
# 6     -0.006405
# 7      0.048686
# 8     -0.017958
# 9     -0.143059
# 10    -0.034816
#          ...
# 314   -0.011421
# 315   -0.004719
# 316   -0.003928
# 317   -0.013580
# 318   -0.036420
# Name: log_returns, Length: 313, dtype: float64

# %%
df['predictions'].value_counts()
# Out:
#  1.0    159
# -1.0    154
# Name: predictions, dtype: int64

# %%
df['signal'].value_counts()
# Out:
#  1.0    175
# -1.0    138
# Name: signal, dtype: int64

# %% [markdown]
# Try with test Data

# %%
df_test = pd.read_csv('../test_data/ETHUSD.csv')
df_test = format_data(df_test)
df_test.head()
# Out:
#     day        date        close         high          low         open  \
# 6     6  2021-11-23  4341.695776  4386.305480  4064.319448  4088.650975
# 7     7  2021-11-24  4272.610133  4375.576398  4168.147837  4341.696954
# 8     8  2021-11-25  4525.216946  4551.806504  4247.399482  4270.439785
# 9     9  2021-11-26  4040.282001  4552.818755  3917.747777  4525.607985
# 10   10  2021-11-27  4096.358260  4184.699619  4028.972843  4042.034941
#
#            volume  log_returns  signal     lag_1     lag_2     lag_3  \
# 6    47881.297789     0.060320     1.0 -0.041243 -0.035494  0.026876
# 7    33929.019664    -0.016040    -1.0  0.060320 -0.041243 -0.035494
# 8   573224.578712     0.057441     1.0 -0.016040  0.060320 -0.041243
# 9   795001.562496    -0.113351    -1.0  0.057441 -0.016040  0.060320
# 10  405804.518989     0.013784     1.0 -0.113351  0.057441 -0.016040
#
#        lag_4     lag_5
# 6   0.072178 -0.070362
# 7   0.026876  0.072178
# 8  -0.035494  0.026876
# ...

# %%
df_test['predictions'] = lm_full.predict(df_test[cols])
df_test.head()
# Out:
#     day        date        close         high          low         open  \
# 6     6  2021-11-23  4341.695776  4386.305480  4064.319448  4088.650975
# 7     7  2021-11-24  4272.610133  4375.576398  4168.147837  4341.696954
# 8     8  2021-11-25  4525.216946  4551.806504  4247.399482  4270.439785
# 9     9  2021-11-26  4040.282001  4552.818755  3917.747777  4525.607985
# 10   10  2021-11-27  4096.358260  4184.699619  4028.972843  4042.034941
#
#            volume  log_returns  signal     lag_1     lag_2     lag_3  \
# 6    47881.297789     0.060320     1.0 -0.041243 -0.035494  0.026876
# 7    33929.019664    -0.016040    -1.0  0.060320 -0.041243 -0.035494
# 8   573224.578712     0.057441     1.0 -0.016040  0.060320 -0.041243
# 9   795001.562496    -0.113351    -1.0  0.057441 -0.016040  0.060320
# 10  405804.518989     0.013784     1.0 -0.113351  0.057441 -0.016040
#
#        lag_4     lag_5  predictions
# 6   0.072178 -0.070362          1.0
# 7   0.026876  0.072178          1.0
# ...

# %%
df_test['predictions'].value_counts()
# Out:
#  1.0    14
# -1.0     2
# Name: predictions, dtype: int64

# %%
accuracy_score(df_test['predictions'], np.sign(df_test['log_returns']))
# Out:
# 0.5625

# %%
predicted_prob = lm_full.predict_proba(df_test[cols])
df_test['buy_prob'] = predicted_prob[:,1]
df_test['sell_prob'] = predicted_prob[:,0]
df_test.head()
# Out:
#     day        date        close         high          low         open  \
# 6     6  2021-11-23  4341.695776  4386.305480  4064.319448  4088.650975
# 7     7  2021-11-24  4272.610133  4375.576398  4168.147837  4341.696954
# 8     8  2021-11-25  4525.216946  4551.806504  4247.399482  4270.439785
# 9     9  2021-11-26  4040.282001  4552.818755  3917.747777  4525.607985
# 10   10  2021-11-27  4096.358260  4184.699619  4028.972843  4042.034941
#
#            volume  log_returns  signal     lag_1     lag_2     lag_3  \
# 6    47881.297789     0.060320     1.0 -0.041243 -0.035494  0.026876
# 7    33929.019664    -0.016040    -1.0  0.060320 -0.041243 -0.035494
# 8   573224.578712     0.057441     1.0 -0.016040  0.060320 -0.041243
# 9   795001.562496    -0.113351    -1.0  0.057441 -0.016040  0.060320
# 10  405804.518989     0.013784     1.0 -0.113351  0.057441 -0.016040
#
#        lag_4     lag_5  predictions  buy_prob  sell_prob
# 6   0.072178 -0.070362          1.0  0.699521   0.300479
# ...

# %% [markdown]
# Plot ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(df['predictions'], np.sign(df['log_returns']))
auc = roc_auc_score(df['predictions'], np.sign(df['log_returns']))
print('fpr: {}'.format(fpr))
print('tpr: {}'.format(tpr))
print('thresholds: {}'.format(thresholds))
print('auc: {}'.format(auc))
plt.plot(fpr,tpr,label="signal data, auc="+str(auc))
plt.show()
# Out:
# fpr: [0.         0.52597403 1.        ]
# tpr: [0.         0.59119497 1.        ]
# thresholds: [ 2.  1. -1.]
# auc: 0.5326104712897165

# %% [markdown]
# Plot probabilities

# %%
df
# Out:
#      day        date        close         high          low         open  \
# 6      6  2021-01-08  1216.751571  1262.290424  1085.546172  1225.661462
# 7      7  2021-01-09  1277.456309  1305.823731  1171.661108  1216.669204
# 8      8   2021-01-1  1254.720733  1349.475651  1165.847880  1277.548286
# 9      9  2021-01-11  1087.469986  1260.199167   912.604580  1254.659819
# 10    10  2021-01-12  1050.260409  1150.055396  1006.276283  1087.335624
# ..   ...         ...          ...          ...          ...          ...
# 314  314  2021-11-12  4666.496945  4809.226469  4509.583511  4719.821999
# 315  315  2021-11-13  4644.527382  4704.701538  4585.021231  4666.360858
# 316  316  2021-11-14  4626.317297  4695.870000  4514.635312  4647.030000
# 317  317  2021-11-15  4563.918580  4771.690847  4540.045330  4627.312350
# 318  318  2021-11-16  4400.690671  4564.149468  4248.417498  4563.906651
#
#            volume  log_returns  signal     lag_1     lag_2     lag_3  \
# ...

# %%
type(df[cols])
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('../test_data/')

# %%
X = df[cols]
df['predicted_proba'] = lm_full.predict_proba(X)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\craig\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predicted_proba'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[['strategy', 'log_returns']]

plt.plot(test_date,signal_prob[:,1], 'g-', label='Buy Prob')
plt.plot(test_date,signal_prob[:,0], 'r--', label='Sell Prob')
